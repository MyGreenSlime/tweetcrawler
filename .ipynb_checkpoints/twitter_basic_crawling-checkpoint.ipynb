# %% [markdown]
# # Basic Retrieval of Twitter Data
#
# Twitter provides REST APIs you can use to interact with their service. There is also a bunch of Python-based clients out there that we can use without re-inventing the wheel. In particular, Tweepy in one of the most interesting and straightforward to use, so let’s install it:
#
# ```
# pip install tweepy
# ```
#
# ## Getting Twitter API keys
# In order to access Twitter Streaming API, we need to get 4 pieces of information from Twitter: *API key*, *API secret*, *Access token* and *Access token secret*. Follow the steps below to get all these 4 elements:
# * Create a twitter account if you do not already have one.
# * Go to https://apps.twitter.com/ and log in with your twitter credentials.
# * Click "Create New App"
# * Fill out the form, agree to the terms, and click "Create your Twitter application"
# * In the next page, click on "API keys" tab, and copy your "API key" and "API secret".
# * Scroll down and click "Create my access token", and copy your "Access token" and "Access token secret".

# %%
import tweepy

consumer_key = 'fMfhrOtla2moyzUKucMGIWTvn'
consumer_secret = 'BuKrHPQ4P8fq8I8nJ9cevB2wpNxf6igjoVmyaSPDXWUvlkBVz6'
access_token = '2286346634-rntezOjoIb2fkQ9h4GiOwCGhFoOBYt9Uqk5ZYtH'
access_secret = '4a6QI0KHpnxDsDGns4BIpFZMe5w9zdB2GdnyXWqmOvylY'

# Creating the authentication object
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
# Setting your access token and secret
auth.set_access_token(access_token, access_secret)

# Creating the API object while passing in auth information
api = tweepy.API(auth)

# %% [markdown]
# ## 1) Accessing users' timeline
#
# ### 1.1 Your Timeline
# In this example, we'll be pulling the ten most recent tweets from your Twitter feed. We'll do this by using the API object's `home_timeline()` function. We can then store the result in a variable, and loop through it to print the results.

# %%
# Using the API object to get tweets from your timeline, and storing it in a variable called public_tweets
public_tweets = api.home_timeline()
# foreach through all tweets pulled
for tweet in public_tweets:
    # printing the text stored inside the tweet object
    print(tweet.text)
    print()
# Out:
# RT @2ch_meigen_: 上司に「さようなライオン！」て言って帰社したらクビになった
#
# 1：ID:9smo5yN80
# 君もう明日からこなくていいよ＾＾；だって
# 挨拶すると友達増えるんじゃねえのかよ！
#
# 3：ID:jX14xuH00
# リストライオンｗｗｗｗｗｗｗｗｗｗ…
#
# [Status AU
# เป็นโลกแนวแฟนตาซีล้ำยุค เครื่องมือบางอย่างทันสมัยพวกจักรกล เช่นกล้องถ่ายรูป หุ่นเชิดของสาวน้อยหมวกแดง เ… https://t.co/HI75ld6WPl
#
# Title :[AU]Under The Moonlight
# Pairing :Joseph(Moonlight Gentleman) ×Naib(Infected) #josephnaib
# Rate :R18 (Privatte… https://t.co/WnHO5miFUp
#
# RT @akiko_lawson: ＼ #カフェラテ無料プレゼント ！／
# 生乳100％使用牛乳でまじりけのないおいしさ！フォロー＆リツイートで10日間連続、毎日1万名様にカフェラテが当たります(^^)
# 9日目は2/27 10:59まで♪ #ローソン #マチカフェ https:/…
#
# RT @sakai_kazuyoshi: 純烈は上手さを競っちゃダメ。歌でも何でも勝たれへん。だけど積み重ねだけは怠っちゃダメ。上手い人たちが上手さにあぐらかいて寝てる隙に双六をコッソリと進めてきたグループです。今、学生さんたちは試験のシーズンですよね。落ちこぼれなりに勝ちに行…
#
# お昼のVS https://t.co/ulMLbtR3kL
#
# RT @tigerfuak_staff: おはです♬
# 3/9(土)、ショーで初のフークさん、
# 新しい力『ファイブスターモード』
# 発動！
# …の予定w
# みんな、観にきてね♡
# #下関 #ローカル #ヒーロー #タイガーフーク https://t.co/jOI5UY9r2y
#
# RT @Qrais_Usagi: 8コマ漫画？？？「刑務所」/Animal prison https://t.co/vZozmqMIH1 https://t.co/4nQ4b9vjmH
#
# อันนั้นแค่บังเอิญ หนูก็ไม่คิดว่าจะเป๊ะขนาดนั้นไง55555
#
# กะแค่แบบใกล้ๆลงหัวสักนิด อาจจะกะเวลาเดินหน่อย แต่ใครถอนดอกปี… https://t.co/uaNUGShZIm
#
# จำได้ว่าเคยเล่นอู่ฉางแล้ววาร์ปแบบพอดียืนหลังเซอร์เป๊ะๆสองสามรอบ อยากรู้ความรู้สึกของเซอร์เหมือนกันว่าคิดยังไงกับตุ้… https://t.co/WhpMRWOr3y
#
# RT @itabashi_times: 正解は赤塚新町公園の少女の像でした。
# 赤塚新町公園は「生き粋いたばしまちなみ景観賞」を受賞しているそう。
#
# https://t.co/3R45ZJKzsy
#
# #いたばしココどこでしょ #赤塚新町
# (しのりのつぶやき) https://t.…
#
# RT @SomaliHina: 人間の体重計の上に自分で籠を動かして、更には奥にヒヨコの人形を持ち込むこだわりっぷり🐥秘密基地  #ソマリ #猫のいる暮らし #猫画像 https://t.co/tMVesPAn3W
#
# なんかめっちゃ上手く作れた https://t.co/j0VNHrVtbT
#
# RT @kittyarchive: no u come here hooman https://t.co/LgEUSWquHP
#
# つかれた…いやし、いやしをくれ…
#
# จู้คนานแล้วดีจุย ส่วนอันนั้นคือเจอฮันกลัวโลง ปล่อยเราล้มแล้วไม่จับนั่งถถถ
#
# จบที่คงรำคาญ เลยปล่อยเก๋ลงหลุม https://t.co/XlOxivdwj5
#
# RT @yoshino_0527: ダルライザー（福島県のご当地ヒーロー）の映画、見たすぎるよね？ね？
#
# RT @granblue_en: Primaniacs is set to release a 4th series of GBF character fragrances, based on the Society members: Zeta, Vaseraga, Beatr…
#
# 【商品情報】
# 仮面ライダーに新しいフィギュアシリーズが登場！
# その名も「RIDER's ANTHEM」！
# 全14か所の可動でポージングが可能！
#
# 仮面ライダーザダイナーにも入荷されました！
# ご来店されたついでに是非、回していってく… https://t.co/lbFn5koY32
#
# แฟนถามว่าทำไมพูดครับ นี่ก็ตอบว่าอยากให้สภาพตัวเองใช้สรรพนามก้ำกึ่งอยู่ ถ้าภาษาไทยมีแค่ไอกับยูก็ดีสิ
# แล้วรู้สึกการใ… https://t.co/Zx6TTfpnrX

# %% [markdown]
# ### 1.2 Tweets from a Specific User
# In this example, we'll simply pull the latest twenty tweets from a specific user.
#
# From the <a href="http://docs.tweepy.org/en/v3.5.0/api.html" target="_blank">Tweepy documentation</a>, we find that the `user_timeline()` function is what we're looking for.
#
# <img src="function_user_timeline.png" alt="The user_timeline() function" title="The user_timeline() function" width="60%" align="left" />

# %% [markdown]
# We can see that the `user_timeline()` function has some useful parameters we can use, specifically `id` (the ID of the user) and `count` (the amount of tweets we want to pull). Note that we can only pull a limited number of tweets per query due to Twitter's <a href="https://developer.twitter.com/en/docs/basics/rate-limiting" target="_blank">rate limits</a>.
#
# We can create variables to store the amount of tweets we want to pull (count), and the user we want to pull them from (name). We can then call the `user_timeline()` function with those two parameters.

# %%
# The Twitter user who we want to get tweets from
name = "@_Greenslime_"

# Number of tweets to pull
tweetCount = 1000

# Calling the user_timeline function with our parameters
results = api.user_timeline(id=name)

# foreach through all tweets pulled
for tweet in results:
    # printing the text stored inside the tweet object
    print(tweet.text)
    print()
# Out:
# อยากถามพี่ลูกหนูว่า เต็มเพลงได้ไหม คือดีอ่ะ
#
# @kwsrtp ผู้ชายไหมอ่ะ
#
# @kwsrtp มึงเจอกูตอนไหนวะ อมรเหรอ
#
# เรียนกับจารย์ภารุจคือดีมาก เรียนตัวเดียวแต่ทำให้เข้าใจทั้งเทอมที่เรียนมาอ่ะ เกินไปอ่ะจารย์ 55555
#
# แต่บะเรื่องก็มีความน่าสนใจในตัวมัน
#
# @skconan ว่าละต้องมีคนคิดเหมือนกัน จริงๆ อยากให้น้องรู้จักภาพรวม แบบเรียนคอมไม่ได้มีแค่ทำ web นะ อยากให้เห็นภาพกว้า… https://t.co/2qTe8cKTJ8
#
# อยากทำแนะแนวเด็ก รร เก่ามาก เรื่อง ภาคคอมเข้าดีไหม 5555
# กลัวคนเข้ามาและผิดหวัง
#
# @skconan น้ำตาไหลสิ 555 me too clean data ยากจัด
#
# RT @JennluvxJae: อิสัส กุขำแรงมาก5555555555555555555555555555555555555555555555
# #อนาคตใหม่
# #ฟ้ารักพ่อ
# #พลังประชารัฐ
# #ฟ้ารักพ่อเพราะนโยบาย…
#
# เสียดาย.
#
# RT @SkulLaeEy: เจอในเฟช เขาบอกให้ดู 4 วิแรกแล้วเลื่อนไปตอนท้ายๆนี่ก็ลองทำ นั่งขำอยู่ 10 นาทีอีสัด 5555555555555 https://t.co/FVUpBBePy8
#
# ดูจากงานที่ทำในตอนนี้ละ คงหนีไม่พ้น HPC แน่เลย
#
# @skconan รวยนะทำ โปรเจคจบอ่ะ แต่ก็นะ มันพูดยาก
#
# พอ ปี3 ละชีวิตเริ่มจริงจัง
#
# RT @jhxship97: ข้าวเหนียวมะม่วง i sus 555555555555555555555 #tucuball73 https://t.co/oAlpckvsIn
#
# RT @onou3: ทั้งจ้าว ทั้งรัฐ ทั้งสื่อ เล่นหมดแล้วจ้าาาาาาาา #TUCUBALL73 https://t.co/V1xJnlF3o8
#
# RT @monetacaffeine: ดีเทล
# 1 : นาฬิกา
# 2 : ประเทศไทยอยู่บนโต๊ะ
# 3 : นั่งทับรัฐธรรมนูญ (?)
# 4 : นั่งทับคนจนถือบัตรคนจน
# #TUCUBALL73 แซ่บมาก ชอบ h…
#
# RT @pnic_k: ชอบอันนี้แม่งโครตจริง #TUCUBALL73 https://t.co/Nd527Dts5I
#
# RT @PePPeR0528: ป้ายนี้โดนเก็บบบบบ #TUCUBALL73 https://t.co/rGFkmA5VBK
#
# RT @evermini_: #เมอา conan ของคนอื่น กับ conan ของฉันตอนอ่านแท็ก อห.เอ้ยผิดเองงง https://t.co/uSP4mS8XyN
#
# ให้กูรอมา 3 อาทิตย์ บอก ไม่ match เอ้าอีเหี้ย เทสมึงก็ไม่ส่งมาให้ทำ
#
# RT @iannnnn: ทำไมคุณไม่สอนพนักงานให้วางแผนการเงิน https://t.co/DZHd2qAdVV
#
# RT @kupenmaew: ลูกน้องแมวกะลังนั่งรำลึกถึงบรรพบุรุษ https://t.co/HJ4eH8uCRA
#
# RT @pompomcoffee: แอบสงสัยว่าผญผมยาวหลายคนอยู่ได้ยังไงโดยไม่สระผมหลายวันหรือเป็นอาทิตย์ คือถ้าอยู่แต่ในบ้านอยู่แต่ในห้องแอร์ ไม่มีเหงื่อ ไ…
#
# แคนแคน แม่งน่ารักกกกกกก
#
# ชอบอยู่แล้ว แต่ก็ชอบมากขึ้นไปอีก
#
# มีagoda อ่ะดีมาก แต่test พี่แกยากจัง 555
#
# หาที่ฝึกงานแม่งเหมือนคุยกับคนไม่มีใจ เดี๋ยวตอบบ้าง เดี๋ยวหายไปเลย เดี๋ยวบอกให้ส่งเมลมา และตอบว่าไม่รับintern เอ้าอีเหี้ย!!!
#
# เห้อมมมมมม
#
# RT @animalsmm_: เป็นตุ๊กตาลม จำเป็นต้องพริ้วขนาดนี้มั้ยอ่ะ5555555555555555555555555555555555555555555 https://t.co/VSmMkTeeEf
#
# แม่ค้าร้านกิมจิกูคือน่ารักมากอ่ะ อีสัส ดีกับใจเกินไปแล้ววว
# อีเหี้ย
#
# RT @jarvaa: Pornhub ฟรี แต่ Nexflix จ่ายตัง ... เด็กจะเข้าอะไร
#
# @skconan แบบเห็นโจทย์และแม่งน้ำตาไหล ตอนนี้ยังเลือกภาษาไม่ถูกเลยแม่ง
#
# @skconan Internet dowload manager อ่ะ. ที่โปรแกรมโหลดไฟล์อ่ะ เดือดจัด
#
# แต่ก็ดี เรามักเรียนรู่้ได้อย่างรวดเร็วจาก Deadline
#
# เริ่มสงสัยใน agoda ว่ากูส่งฝึกงาน Tech internship นะไม่ใช่สมัครงานจริง
# รอบแรก ถาม Design pattern, Software Arch มาร… https://t.co/N0fHLnoXCw
#
# @skconan ใช่ ถ้าไม่ให้ฝึกและจะหาประสบการณ์ไหนจริงๆวะ
#
# ทำไมไม่บอกเค้าไปว่า you can challenge me แทนวะ อีสัส
#
# RT @MindMelodyWorld: โดนอีกแล้ว!!!
# มาจ้างหรือขอซื้อกันดีๆสิ อาชีพเรา งานเรา มาทำให้มันถูกสิ
#
# ไม่ใช่คลิกขวาแล้วเซฟแอ้ด หรือเอาไปดราฟแบบนี้…
#
# บางทีก็อยากสวนเพื่อนตัวเองนะว่า อีสัส ไมมึงไม่ทำเองวะ
#
# RT @Meawgolf_: การถ่ายรูปกลุ่มจะไม่ซ้ำซากอีกต่อไป อิเวง 5555555555555555 https://t.co/lqhBTMam1l
#
# ไม่พอใจตัวเองมากๆๆ
#
# เกลียดความพ่ายแพ้นี้จัง
#
# ถ้าติดก็ปฏิหารย์ละสัส
#
# RT @taan35843956: เห็นเด็กบ่นเรื่องที่โรงเรียนยืนยันจะให้เข้าแถวกลางฝุ่นแล้วก็รู้สึกว่า
# ประเทศเรานี้ จะไม่งี่เง่าสักเรื่องให้ชื่นใจได้มั้ย…
#
# @skconan คือมันมีแข่งanalytic skill ไงเลยอยากไป
#
# RT @ter_nawapol: ชนะทุกข่าวและทุกมีมของวันนี้ไปเลยครับ https://t.co/D9xplVvEua
#
# @skconan ใช่เลย ไปเหรอ
#
# คือมึงจัด hackathon วันจันอังคาร นี่ใครจะไปแข่งให้มึงวะ นอกจากพนักงานบริษัทมึงเอง
#
# ฮัลโหล กูใช้ chrome อีสัส https://t.co/oDpMy913ru
#
# @pratcheeze congratulation ครับ วันนี้ไม่ได้ไป ขอโทษด้วยครับ ยังอยู่บ้านอยู่เลย
#
# โคตรเท่ https://t.co/nJP1CwM2fq
#
# @Nook_ktw ว้าวอะไร กูยังไม่ติด
#
# น้องมาปรึกษา “เกรดไม่รู้ดีไหม 3.84 ได้ b+ 2ตัว  ขัดใจ”
# อีเหี้ย กูเรียนมา 5เทอมเกรดกูยังมากสุดยัง ไม่ถึงเลข3เลยสัส
#
# Agoda เรียกสัม แต่ตอนนี้กูโล่งมากอีสัส
#
# วิ่งหนีเอฟมา รอบนี้แม่บอกว่าไม่เอาละนะ แม่เหนื่อย 5555
#
# ปี3เทอมที่แล้ว นี่สนุกสัสเลย นะ มินเซค 2 ตัว รอดF ไป1 อีกตัวรอต่อไป
#
# วอนอาจารย์อย่าเที่ยวนาน เกรดกูยังออกไม่ครบ ลุ้นเอฟอยู่โว้ย
#
# @mindblings ทำประกันไหมครับ
#
# Bad day เหี้ยๆ
#
# โมโหมากอีเหี้ย
#
# ไม่เคยรู้สึกเหี้ยปีใหม่ปีไหนเท่าปีนี้
#
# คือก็รู้แหละเค้าตอบตาม มารยาท แต่กูก็ยังดีใจ
#
# เค้าเขีบนโค้ดทั้งหมดโดยไม่รันได้ไงวะ
#
# Read
#
# กู ขก อ่านโค้ดคนอื่นเว้ยยย
#
# สงสารก็สงสารนะพี่ พี่ก็รู้ว่านี่ปีสุดท้าย พี่ก็ยังไม่ทำเหี้ยไรเลย ยังจะมาใข้กูทำอีก ขนาดกูบอกว่าติดตรงไหนให้ช่วยไหม… https://t.co/1SiDSGQi6X
#
# @fahfinkfink @mindblings ยุ่ง!!!!
#
# @mindblings ถึงละบอกด้วย เป็นห่วงนะ:)
#
# ใจไม่ดีเลยครับ
#
# เหยียดเก่ง
#
# เอาฉันออกจากโลกความฝันนี้ที
#
# RT @phyxinon: ┏━━┓┏━━┓┏┓ ┃┗┛┃
# ┗━┓┃┃┏┓┃┃┃ ┗━━┛
# ┏━┛┃┃┃┃┃┃┃ ┏━━┓
# ┃┏━┛┃┃┃┃┃┃ ┃┏┓┃
# ┃┗━┓┃┗┛┃┃┃ ┃┗┛┃
# ┗━━┛┗━━┛┗┛ ┗━┓┃
#
# จริงๆก็อยากบ้าพลังนะ
#
# เป็น christmas ที่ ดีอีกปีนึง
#
# RT @_ty20xx: มึงเคยทุ่มอ่านวิชานึงหนักๆแล้วมึงสอบตกปะ https://t.co/x71SCyqjWW
#
# อยากทำติ๊กเกอร์ไลน์เป็นของตัวเองนะ แต่แค่คิดก็ขี้เกียจและ
#
# น้ำตาไหล อีเหี้ย ไม่รู้เขินอะไรกว่านี้และ
#
# สมองมาทำงานไรตอนช่วงนี้ตลอดวะ
#
# Fuck you parser
#
# น้ำตาไหลแปป
#
# คิดถึง คาริน
#
# เก็บห้องในรอบ4เดือน อีเหี้ยโคตรรก สงสัยว่ากูอยู่ไปได้ไง
#
# RT @LantoAikawa: กูนั่งตัดเล็บเท้ายังมีสมาธิกว่าอ่านชีทสองแผ่นตรงหน้าอีก กูทำได้ไงวะ
#
# ตั้งแต่เข้ามหาลัยมา ความขยันขันแข็งที่กูพยายามเข้ามหาลัย แม่งอยู่ไหนวะ อ่านคืนเดียวทุกตัวเลยสัส
#
# 5555
#
# เรียน os มา และ ก็ทำให้จัด priority การอ่านสือได้ดีจริงๆ ตอนนี้อ่านสือแบบ
# FGF F Grade First
#
# ภาคคอมเป็นภาคที่ อ่าน one night ทุกตัว และเสือกคะแนนดีด้วยนะ แต่ขอโทษ ยกเว้นกู 5555
#
# @aniimato ขอตั๋วฟรี
#
# RT @Jswxxxx: เออว่ะ สุดแล้วโพสต์นี้ #บัตรคนจน https://t.co/qE1WFVX5EG
#
# https://t.co/L3ctBWJ5yk
#
# https://t.co/NlZUWeunI9
#
# RT @Kwajatungoffice: ปริศนา สายฟ้าช็อต https://t.co/Ai2vNiS8qf
#
# ภาคกูดีแม่งทุกอย่าง ยกเว้นกู
#
# ไม่เคยเจอใครตั้งใจสอนเท่า จารย์ภารุจ แต่ไอ้สัส กูเหี้ยเองแม่งไม่เคยเรียนเลย
#
# @mindblings ย้ายมึงไป อัคคาบันอ่ะ
#
# RT @_Agent11: ประทับใจประโยคนึงของรอนมาก มันเป็นตอนแฮรี่เครียดที่เดรโกมาท้าดูเอลเลยมาปรึกษากับรอน รอนบอกถ้าสู้ด้วยคาถาไม่ได้ก็ปาไม้ทิ้งแล้ว…
#
# RT @minevith: ฮือตลกสัส เค้าเล่นทินเดอร์ละเจอ Jesus ละดูพอแมทซ์กันแล้วเค้าทักมาดิ 55555555555555555555555555555555555555555555555555555 htt…
#
# RT @Kwajatungoffice: ขอย้ำว่านี่คือเหตุการณ์จริง
# ไข่มุกที่เห็นในภาพก็คือไข่มุกจริงๆไม่ใช่ตัวแสดงแทน
#
# #กว่าจะถึงออฟฟิศ https://t.co/GIYB9T6k…
#
# เราน่าจะสอนให้เด็กหัดตั้งคำถาม
#
# RT @pewpillow: ทำไมอ่านหนังสือมันทรมานแบบนี้
#
# RT @punch_memox: อันนี้เหี้ยมาก 55555 https://t.co/5K3Yy9dBGn
#
# ปี 3 งาน software eng แม่งเป็นงานที่ทำให้เพื่อนแตกหักกันได้มากที่สุดและเป็นงานกลุ่มที่ทำให้เห็นว่าคนนั้นเป็นไง แม่ง… https://t.co/bUXM9Zz74X
#
# เรียนมหาลัยมา ปีนี้คริสมาสต์ เลือดสาดสุด 55555
#
# อีเหี้ย เขิน https://t.co/I1ZYKvzVhy
#
# RT @Kwajatungoffice: กุลางานมาแสดงความเสียใจกับมึงเลยนะน้องรัก https://t.co/FcmZ0murc8
#
# กูจะรอดพ้น ไปได้ไหมเนี่ยยยย
#
# @ppmmmp ผิดที่ฉันยอม ยกใจให้เธอไป
#
# Keyakizaka 46 แม่งคุณภาพจริง รู้งี้ซื้อแผ่นไว้หน่อยดีกว่า
#
# สัสเขินเลย
#
# รู้ไหมว่าเธอเป็นคนน่ารักดี
#
# ป่วยอีกละสัส
#
# ทุกคนมนภาคมึงจะแดกกันเองไม่ได้นะสัส ผู้หญิงจะไม่เหลือแล้วววววว
#
# RT @Mameaw14: พึ่งสังเกตว่าเสื้อสกรีนหลังห้าสีสปอนหลักได้สีด้วย แต่ของ ThoughtWorks นี่คือโลโก้ไม่มีสีชะ เลยกลืนไปเลย #bcbk9 https://t.co/8…
#
# RT @dtinth: มางาน #bcbk9 ได้ความรู้ ได้เจอเพื่อนเก่าๆ ที่ไม่ได้เจอนาน ได้รู้จักคนใหม่ๆ เหมือนทุกรอบ ดีใจที่ได้มางานนี้ครับ~ หลายคนที่มาครั้…
#
# งงกับเพื่อนที่ว่า ไม่รู้ว่าเขียนอะไรลงไปในโค้ด คือถ้ามึงไม่รู้คนอ่่นก็ไม่รู้โว้ยยย
#
# โรงเรียนฟันยับ ครับงานนี้ ขวดละ 5บาท 555555 https://t.co/PBvbxTgZzR
#
# @fahfinkfink ได้เหรอืเจอกัน abac
#
# เอาจริงนะไม่อยากให้เพื่อนแม่งเกลียดกัน ไม่อยากให้ทุกคนแบนใส่ ใช่กูก็ไม่ชอบวิธีการทำงานแม่งนะ แต่ก็ไม่อยากให้ทุกคนแบนมัน
#
# ฝันเมื่อเช้าเป็นอะไรที่บอกไม่ถูกจริงๆ
#
# @pratcheeze ใช่มันเป็นแค่ตัว boost แต่เห็นเพื่อนเก่งและก็อยากจะก้าวตาม
#
# อยากรู้แม่งเิาเวลาที่ไหนไปอ่านระดับล่างจัดๆวะ
#
# มีGod ที่ภาคคนนึงแม่งซิ่วมาสองปี ก็ตอนนี่อยู่ปี1 มันก็อายุเท่าปี 3 อ่ะ และแม่งคือเก่งมากถามไรตอบได้ เจอปัญหาเหี้ยไร… https://t.co/JmiUAvSWpw
#
# เมื่อไหร่จะเก่งอ่ะดนนนนน
#
# @SpongeFong HBD ครับ get A เยอะ 555
#
# ปากบอกไม่ได้บังคับนะ แต่ได้ชมกิจกรรม มหาลัย และแม่งกิจกรรมที่ได้ของมหาลัยมีแค่จิ๋มมด
#
# อยู่เกษตรมาจะสามปี ก็ยังไม่เข้าใจว่า จะให้ปี1มาทำไม คือแม่งงานรับปริญญาคนที่จบไปแล้ว หน้ากูก็ไม่เคยยเห็นสนิทก็ไม่ส… https://t.co/f8pYCasX52
#
# ชอบๆ
#
# ดูละอึดอัดเหี้ยๆ
#
# เหมือนน้องเหงาอ่ะครับ
#
# ดีกับใจไม่เปลี่ยน
#
# มุ่งหน้าเต็มกำลัง
#
# ช่างแม่งก็ไม่ได้ด้วยนะ 5555
#
# พอนึกถึงก็เจอเลย 5555
#
# รู้นะว่าต้องทำไงอต่ไม่ทำ
#
# @aniimato ขี้เสือกไง
#
# เชิญร่วมงาน BarCamp Bangkhen 9 ณ มหาวิทยาลัยเกษตรศาสตร์ via @blognone https://t.co/sGWwEsLhLW
#
# เป็น*
#
# บางทีก็กลัวตัวเองเป๋นซึมเศร้านะ
#
# RT @barcampbangkhen: คำถามที่พบบ่อยในงาน Barcamp Bangkhen หาคำตอบกันได้ที่นี่ https://t.co/hpmTIP6HCE
# ใครมีคำถามเพิ่มเติมสามารถติดต่อสอบถา…
#
# RT @barcampbangkhen: สิ้นสุดทุกการรอคอย เพราะ Barcamp Bangkhen เปิดลงทะเบียนแล้ว!
# ลงทะเบียนได้ที่ https://t.co/u48ZmlIQIe ตั้งแต่วันนี้ -…
#
# สิ่งที่ทำให้เราเห็น เงินเฟ้อได้อย่างชัดเจน ก็คงจะเป็น ผลิตภัณฑ์ จาก apple นี่แหละ นับวันขายไตยังไม่พอซื้อเลย
#
# กลุ่มตัวอย่างไง 555 https://t.co/cHXD2U8tSO
#
# พอพบว่าพรุ่งนี้ต้องไปเรียน ก็เกลียดวันจันทร์ขึ้นมาทันที
#
# เช้าใจไหม ว่าชอบโว้ยยยยยยยยยยยย
#
# ไอ้เหี้ย ioi ทั้งคู่
#
# กูมากับเจ๊ 3คน อีสัส
#
# อีกทริปได้โปรดเอากูไปด้วย
#
# สาวๆ ญป นี่น่ารักจริง
#
# ดินแดนแห่งเหล่าไอดอล รอเราอยู่
#
# ขอเหอะ อย่าล่าสัตว์เลย
#
# RT @GratitudeDNA: จนท.หน่วยงานดูแลเรื่องสัตว์น้ำและสัตว์ป่าไปเที่ยวแอฟริกาแล้วไล่ฆ่าสัตว์ป่าอย่างสนุกสนานรวม14ตัวในจำนวนนั้นมีครอบครัวลิงบา…
#
# เป็นมนุษย์ที่ชั่งแม่งไม่เคยได้
#
# ทำไมกูเครียดขนาดนี้นะ 5555
#
# RT @barcampbangkhen: สำหรับใครที่ยังไม่รู้ว่า Barcamp คืออะไร เรามีคำตอบ กดที่ลิงค์กันเลย! https://t.co/UI3RDZevQv
#
# จัดเสือผ้าไปเที่ยว ได้แต่ถามตัวเองว่า นี่ปกติกูแต่งตัวอะไรของกูวะ
#
# ชอบโว๊ยยยย
#
# @kwsrtp หัวร้อนเพื่อน แม่งขิงใส่ 5555
#
# ตอบไม่ได้เองก็อย่าปากดี
#
# ปี3 นี่เวลาหายใจกูอยู่ตรงไหนวะ
#
# @mindblings กูๆๆๆ คบกู
#
# RT @IHEERWAN: เหนื่อยเกินไปแล้วว อยากชาจแบต
#
# หัวร้อน
#
# เข้าใจและmidterm ได้เยอะ final ก็ไม่สนุกเป็นยังไง อีเหี้ย วันแรกก็เครียดเลย จะ f ไม่ f จะลองเสี่ยงดูอีกซักนิด
#
# จารย์น่ารักกกกก
#
# จารย์ ผมขอโทษ
#
# เป็นครั้งแรกกับการไม่ตัเงใจเรียน ครั้งนี้ 555 คือ สัมผัสได้ถึงความทุ่มเทของจารย์ผ่าน คลิป
#
# RT @nisbutter: พ่อ ผมเห็นสายตาที่กู๋เมธมองกิ๋มคริส มันเหมือน ...#เลือดข้นคนจาง https://t.co/7U36mRChys
#
# ใครบอกให้มึง อ่าน os วันเดียวก่อนสอบ อีสัส หนักหน่วงมาก
#
# ดีนะสอบ สี่โมง
#
# ตอนนี้ m150 ก็ เอากูไม่อยู่ละสัส แดกๆไปหลับคาคอม ตื่นมาปิดไฟนอน 555
#
# กูโง่ด้วยแหละประเด็น
#
# 5555 ขอmean นะครับ อย่าให้ต่ำกว่านี้เลย ได้โปรด
#
# toc นี่กูจะได้ไรมาวะ อีเหี้ยว่าอ่านไปละ เจอนิยามไป ไอ้สัส ตายห่าเลย และประเด็นคือ แม่งเป็นช้อย
#
# RT @_xvith: 55555555555555555555555555555555555555555555555555555555555555555 https://t.co/wl7ZYXu8QF
#
# RT @omscw: เฉลยแล้วเหตุผลที่ภัสสรรีบร้อนวิ่งออกจากบ้าน #เลือดข้นคนจาง https://t.co/4dTiTXhCx9
#
# RT @Muay_Panda: ได้กระเป๋ามาใบนึงจ้า ถ้าเงียบหายไปขอให้รู้ไว้ว่าโดนรวบ https://t.co/cbR4oxSkTK
#
# RT @rrestp: บ้านเราเครื่องปริ้นเสียอะ ฝากหน่อยได้ป่าว https://t.co/09BxbWo4df
#
# กูเข้าใจsofteng ละอีเหีีย เอกสารเยอะจัด
#
# เราสนิทกันน้อยลง?
#
# กรุงโรมไม่ได้สร้างเสร็จในวันเดียว แต่ 8 วันหลังสอบ กูต้องมีส่ง
#
# ทุกๆสามปีจะเครียด1ครั้งเหรอวะ
#
# เครียดโว้ยยยยย
#
# @pratcheeze ฝากพี่วานไปคอนแกรทละ
#
# @pratcheeze งานไม่เสร็จอ่ะ ตอนแรกว่าจะไป แต่ปั่นไม่ทันเลย
#
# พอไม่ได้ทำ probsolveนานก็ลืม
#
# RT @barcampbangkhen: เตรียมตัวให้พร้อม #bcbk9 กลับมาแล้ว! https://t.co/EoZgnLoF3c
#
# แล้วใครจะรับกกูวะ
#
# กูอยาก เขียน about me ใน resume ว่า กูชื่อดน กูคือ คนที่รักการนอนเป็นอย่างมาก และที่สำคัญ กูขี้เกียจ !!!!
#
# RT @aphichayayeeh: ก่อนเข้ามหา'ลัย     VS    หลังเข้ามหา'ลัย
# #ชีวิตมหาลัย #ตีแผ่ชีวิตมหาลัย https://t.co/p7siUe8Nrb
#
# มึงมาแชร์โค้ดกันก็ได้นั่นเพื่อนกันนะ ไม่ใช่คู่แข่ง
#
# ทีตอนพวกมึงลอกการบ้านกัน ต้นฉบับเค้ายังไม่ด่าเลย มึงลอกกันเหมือนจนนึกว่า ถ่ายเอกสารมา
#
# ถ้าตัว ideaมันคล้ายกัน  ทำไมไม่วัดกันที่productไปเลยวะ ถ้าจะทะเลาะกันว่า copy idea เนี่ย
#
# @skconan เคารพรุ่นพี่ด้วย e71

# %% [markdown]
# ### The JSON behind the Results
# In the example above, we printed the text from each tweet using `tweet.text`. To refer to specific attributes of each tweet object, we have to look at the JSON returned by the Twitter API.
#
# The result you receive from the Twitter API is in a JSON format, and has quite an amount of information attached. You can see the entire returned JSON object here.

# %%
import json
# The Twitter user who we want to get tweets from
name = "@_Greenslime_"

# Number of tweets to pull
tweetCount = 20

# Calling the user_timeline function with our parameters
results = api.user_timeline(id=name, count=tweetCount)

# foreach through all tweets pulled
for tweet in results:
    # printing the tweet object in a JSON format.
    print(tweet)
    print()
# Out:
# Status(_api=<tweepy.api.API object at 0x00000222DCE694A8>, _json={'created_at': 'Wed Feb 20 10:12:01 +0000 2019', 'id': 1098163356853166081, 'id_str': '1098163356853166081', 'text': 'อยากถามพี่ลูกหนูว่า เต็มเพลงได้ไหม คือดีอ่ะ', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': []}, 'source': '<a href="http://twitter.com/#!/download/ipad" rel="nofollow">Twitter for iPad</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 864638390, 'id_str': '864638390', 'name': 'คุณหยอยหาที่ฝึกงาน', 'screen_name': '_Greenslime_', 'location': '', 'description': 'ก็แค่ผู้ชายหัวหยอยหยอยคนนึง', 'url': 'https://t.co/iKw3FeMKuH', 'entities': {'url': {'urls': [{'url': 'https://t.co/iKw3FeMKuH', 'expanded_url': 'https://medium.com/@dondondiary', 'display_url': 'medium.com/@dondondiary', 'indices': [0, 23]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 213, 'friends_count': 294, 'listed_count': 0, 'created_at': 'Sat Oct 06 12:50:13 +0000 2012', 'favourites_count': 881, 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'verified': False, 'statuses_count': 12498, 'lang': 'th', 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': '8B542B', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme8/bg.gif', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme8/bg.gif', 'profile_background_tile': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1041368010886246401/U5gr1jAC_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1041368010886246401/U5gr1jAC_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/864638390/1492800156', 'profile_link_color': '4EB402', 'profile_sidebar_border_color': 'FFFFFF', 'profile_sidebar_fill_color': 'EADEAA', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': False, 'default_profile': False, 'default_profile_image': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none'}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 0, 'favorite_count': 0, 'favorited': False, 'retweeted': False, 'lang': 'th'}, created_at=datetime.datetime(2019, 2, 20, 10, 12, 1), id=1098163356853166081, id_str='1098163356853166081', text='อยากถามพี่ลูกหนูว่า เต็มเพลงได้ไหม คือดีอ่ะ', truncated=False, entities={'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': []}, source='Twitter for iPad', source_url='http://twitter.com/#!/download/ipad', in_reply_to_status_id=None, in_reply_to_status_id_str=None, in_reply_to_user_id=None, in_reply_to_user_id_str=None, in_reply_to_screen_name=None, author=User(_api=<tweepy.api.API object at 0x00000222DCE694A8>, _json={'id': 864638390, 'id_str': '864638390', 'name': 'คุณหยอยหาที่ฝึกงาน', 'screen_name': '_Greenslime_', 'location': '', 'description': 'ก็แค่ผู้ชายหัวหยอยหยอยคนนึง', 'url': 'https://t.co/iKw3FeMKuH', 'entities': {'url': {'urls': [{'url': 'https://t.co/iKw3FeMKuH', 'expanded_url': 'https://medium.com/@dondondiary', 'display_url': 'medium.com/@dondondiary', 'indices': [0, 23]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 213, 'friends_count': 294, 'listed_count': 0, 'created_at': 'Sat Oct 06 12:50:13 +0000 2012', 'favourites_count': 881, 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'verified': False, 'statuses_count': 12498, 'lang': 'th', 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': '8B542B', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme8/bg.gif', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme8/bg.gif',  ...
#
# Status(_api=<tweepy.api.API object at 0x00000222DCE694A8>, _json={'created_at': 'Wed Feb 20 01:56:38 +0000 2019', 'id': 1098038686912937984, 'id_str': '1098038686912937984', 'text': '@kwsrtp ผู้ชายไหมอ่ะ', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'kwsrtp', 'name': 'bbbbbbb', 'id': 1966182146, 'id_str': '1966182146', 'indices': [0, 7]}], 'urls': []}, 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', 'in_reply_to_status_id': 1098026994552397824, 'in_reply_to_status_id_str': '1098026994552397824', 'in_reply_to_user_id': 1966182146, 'in_reply_to_user_id_str': '1966182146', 'in_reply_to_screen_name': 'kwsrtp', 'user': {'id': 864638390, 'id_str': '864638390', 'name': 'คุณหยอยหาที่ฝึกงาน', 'screen_name': '_Greenslime_', 'location': '', 'description': 'ก็แค่ผู้ชายหัวหยอยหยอยคนนึง', 'url': 'https://t.co/iKw3FeMKuH', 'entities': {'url': {'urls': [{'url': 'https://t.co/iKw3FeMKuH', 'expanded_url': 'https://medium.com/@dondondiary', 'display_url': 'medium.com/@dondondiary', 'indices': [0, 23]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 213, 'friends_count': 294, 'listed_count': 0, 'created_at': 'Sat Oct 06 12:50:13 +0000 2012', 'favourites_count': 881, 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'verified': False, 'statuses_count': 12498, 'lang': 'th', 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': '8B542B', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme8/bg.gif', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme8/bg.gif', 'profile_background_tile': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1041368010886246401/U5gr1jAC_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1041368010886246401/U5gr1jAC_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/864638390/1492800156', 'profile_link_color': '4EB402', 'profile_sidebar_border_color': 'FFFFFF', 'profile_sidebar_fill_color': 'EADEAA', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': False, 'default_profile': False, 'default_profile_image': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none'}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 0, 'favorite_count': 0, 'favorited': False, 'retweeted': False, 'lang': 'th'}, created_at=datetime.datetime(2019, 2, 20, 1, 56, 38), id=1098038686912937984, id_str='1098038686912937984', text='@kwsrtp ผู้ชายไหมอ่ะ', truncated=False, entities={'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'kwsrtp', 'name': 'bbbbbbb', 'id': 1966182146, 'id_str': '1966182146', 'indices': [0, 7]}], 'urls': []}, source='Twitter for Android', source_url='http://twitter.com/download/android', in_reply_to_status_id=1098026994552397824, in_reply_to_status_id_str='1098026994552397824', in_reply_to_user_id=1966182146, in_reply_to_user_id_str='1966182146', in_reply_to_screen_name='kwsrtp', author=User(_api=<tweepy.api.API object at 0x00000222DCE694A8>, _json={'id': 864638390, 'id_str': '864638390', 'name': 'คุณหยอยหาที่ฝึกงาน', 'screen_name': '_Greenslime_', 'location': '', 'description': 'ก็แค่ผู้ชายหัวหยอยหยอยคนนึง', 'url': 'https://t.co/iKw3FeMKuH', 'entities': {'url': {'urls': [{'url': 'https://t.co/iKw3FeMKuH', 'expanded_url': 'https://medium.com/@dondondiary', 'display_url': 'medium.com/@dondondiary', 'indices': [0, 23]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 213, 'friends_count': 294, 'listed_count': 0, 'created_at': 'Sat Oct 06 12:50:13 +0000 2012', 'favourites_count': 881, 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'verified': False, 'statuses_count': 12498, 'lang': 'th', 'contributors_enabled': False,  ...
#
# Status(_api=<tweepy.api.API object at 0x00000222DCE694A8>, _json={'created_at': 'Tue Feb 19 19:27:03 +0000 2019', 'id': 1097940647615459329, 'id_str': '1097940647615459329', 'text': '@kwsrtp มึงเจอกูตอนไหนวะ อมรเหรอ', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'kwsrtp', 'name': 'bbbbbbb', 'id': 1966182146, 'id_str': '1966182146', 'indices': [0, 7]}], 'urls': []}, 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', 'in_reply_to_status_id': 1097924620932399104, 'in_reply_to_status_id_str': '1097924620932399104', 'in_reply_to_user_id': 1966182146, 'in_reply_to_user_id_str': '1966182146', 'in_reply_to_screen_name': 'kwsrtp', 'user': {'id': 864638390, 'id_str': '864638390', 'name': 'คุณหยอยหาที่ฝึกงาน', 'screen_name': '_Greenslime_', 'location': '', 'description': 'ก็แค่ผู้ชายหัวหยอยหยอยคนนึง', 'url': 'https://t.co/iKw3FeMKuH', 'entities': {'url': {'urls': [{'url': 'https://t.co/iKw3FeMKuH', 'expanded_url': 'https://medium.com/@dondondiary', 'display_url': 'medium.com/@dondondiary', 'indices': [0, 23]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 213, 'friends_count': 294, 'listed_count': 0, 'created_at': 'Sat Oct 06 12:50:13 +0000 2012', 'favourites_count': 881, 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'verified': False, 'statuses_count': 12498, 'lang': 'th', 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': '8B542B', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme8/bg.gif', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme8/bg.gif', 'profile_background_tile': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1041368010886246401/U5gr1jAC_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1041368010886246401/U5gr1jAC_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/864638390/1492800156', 'profile_link_color': '4EB402', 'profile_sidebar_border_color': 'FFFFFF', 'profile_sidebar_fill_color': 'EADEAA', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': False, 'default_profile': False, 'default_profile_image': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none'}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 0, 'favorite_count': 0, 'favorited': False, 'retweeted': False, 'lang': 'th'}, created_at=datetime.datetime(2019, 2, 19, 19, 27, 3), id=1097940647615459329, id_str='1097940647615459329', text='@kwsrtp มึงเจอกูตอนไหนวะ อมรเหรอ', truncated=False, entities={'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'kwsrtp', 'name': 'bbbbbbb', 'id': 1966182146, 'id_str': '1966182146', 'indices': [0, 7]}], 'urls': []}, source='Twitter for Android', source_url='http://twitter.com/download/android', in_reply_to_status_id=1097924620932399104, in_reply_to_status_id_str='1097924620932399104', in_reply_to_user_id=1966182146, in_reply_to_user_id_str='1966182146', in_reply_to_screen_name='kwsrtp', author=User(_api=<tweepy.api.API object at 0x00000222DCE694A8>, _json={'id': 864638390, 'id_str': '864638390', 'name': 'คุณหยอยหาที่ฝึกงาน', 'screen_name': '_Greenslime_', 'location': '', 'description': 'ก็แค่ผู้ชายหัวหยอยหยอยคนนึง', 'url': 'https://t.co/iKw3FeMKuH', 'entities': {'url': {'urls': [{'url': 'https://t.co/iKw3FeMKuH', 'expanded_url': 'https://medium.com/@dondondiary', 'display_url': 'medium.com/@dondondiary', 'indices': [0, 23]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 213, 'friends_count': 294, 'listed_count': 0, 'created_at': 'Sat Oct 06 12:50:13 +0000 2012', 'favourites_count': 881, 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'verified': False, 'statuses_count': 12498, 'lang': 'th', 'contri ...
#
# Status(_api=<tweepy.api.API object at 0x00000222DCE694A8>, _json={'created_at': 'Tue Feb 19 17:50:47 +0000 2019', 'id': 1097916419474255873, 'id_str': '1097916419474255873', 'text': 'เรียนกับจารย์ภารุจคือดีมาก เรียนตัวเดียวแต่ทำให้เข้าใจทั้งเทอมที่เรียนมาอ่ะ เกินไปอ่ะจารย์ 55555', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': []}, 'source': '<a href="http://twitter.com/#!/download/ipad" rel="nofollow">Twitter for iPad</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 864638390, 'id_str': '864638390', 'name': 'คุณหยอยหาที่ฝึกงาน', 'screen_name': '_Greenslime_', 'location': '', 'description': 'ก็แค่ผู้ชายหัวหยอยหยอยคนนึง', 'url': 'https://t.co/iKw3FeMKuH', 'entities': {'url': {'urls': [{'url': 'https://t.co/iKw3FeMKuH', 'expanded_url': 'https://medium.com/@dondondiary', 'display_url': 'medium.com/@dondondiary', 'indices': [0, 23]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 213, 'friends_count': 294, 'listed_count': 0, 'created_at': 'Sat Oct 06 12:50:13 +0000 2012', 'favourites_count': 881, 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'verified': False, 'statuses_count': 12498, 'lang': 'th', 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': '8B542B', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme8/bg.gif', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme8/bg.gif', 'profile_background_tile': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1041368010886246401/U5gr1jAC_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1041368010886246401/U5gr1jAC_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/864638390/1492800156', 'profile_link_color': '4EB402', 'profile_sidebar_border_color': 'FFFFFF', 'profile_sidebar_fill_color': 'EADEAA', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': False, 'default_profile': False, 'default_profile_image': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none'}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 0, 'favorite_count': 1, 'favorited': False, 'retweeted': False, 'lang': 'th'}, created_at=datetime.datetime(2019, 2, 19, 17, 50, 47), id=1097916419474255873, id_str='1097916419474255873', text='เรียนกับจารย์ภารุจคือดีมาก เรียนตัวเดียวแต่ทำให้เข้าใจทั้งเทอมที่เรียนมาอ่ะ เกินไปอ่ะจารย์ 55555', truncated=False, entities={'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': []}, source='Twitter for iPad', source_url='http://twitter.com/#!/download/ipad', in_reply_to_status_id=None, in_reply_to_status_id_str=None, in_reply_to_user_id=None, in_reply_to_user_id_str=None, in_reply_to_screen_name=None, author=User(_api=<tweepy.api.API object at 0x00000222DCE694A8>, _json={'id': 864638390, 'id_str': '864638390', 'name': 'คุณหยอยหาที่ฝึกงาน', 'screen_name': '_Greenslime_', 'location': '', 'description': 'ก็แค่ผู้ชายหัวหยอยหยอยคนนึง', 'url': 'https://t.co/iKw3FeMKuH', 'entities': {'url': {'urls': [{'url': 'https://t.co/iKw3FeMKuH', 'expanded_url': 'https://medium.com/@dondondiary', 'display_url': 'medium.com/@dondondiary', 'indices': [0, 23]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 213, 'friends_count': 294, 'listed_count': 0, 'created_at': 'Sat Oct 06 12:50:13 +0000 2012', 'favourites_count': 881, 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'verified': False, 'statuses_count': 12498, 'lang': 'th', 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': '8B542B', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/ ...
#
# Status(_api=<tweepy.api.API object at 0x00000222DCE694A8>, _json={'created_at': 'Tue Feb 19 17:50:13 +0000 2019', 'id': 1097916277274771456, 'id_str': '1097916277274771456', 'text': 'แต่บะเรื่องก็มีความน่าสนใจในตัวมัน', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': []}, 'source': '<a href="http://twitter.com/#!/download/ipad" rel="nofollow">Twitter for iPad</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 864638390, 'id_str': '864638390', 'name': 'คุณหยอยหาที่ฝึกงาน', 'screen_name': '_Greenslime_', 'location': '', 'description': 'ก็แค่ผู้ชายหัวหยอยหยอยคนนึง', 'url': 'https://t.co/iKw3FeMKuH', 'entities': {'url': {'urls': [{'url': 'https://t.co/iKw3FeMKuH', 'expanded_url': 'https://medium.com/@dondondiary', 'display_url': 'medium.com/@dondondiary', 'indices': [0, 23]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 213, 'friends_count': 294, 'listed_count': 0, 'created_at': 'Sat Oct 06 12:50:13 +0000 2012', 'favourites_count': 881, 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'verified': False, 'statuses_count': 12498, 'lang': 'th', 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': '8B542B', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme8/bg.gif', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme8/bg.gif', 'profile_background_tile': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1041368010886246401/U5gr1jAC_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1041368010886246401/U5gr1jAC_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/864638390/1492800156', 'profile_link_color': '4EB402', 'profile_sidebar_border_color': 'FFFFFF', 'profile_sidebar_fill_color': 'EADEAA', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': False, 'default_profile': False, 'default_profile_image': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none'}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 0, 'favorite_count': 0, 'favorited': False, 'retweeted': False, 'lang': 'th'}, created_at=datetime.datetime(2019, 2, 19, 17, 50, 13), id=1097916277274771456, id_str='1097916277274771456', text='แต่บะเรื่องก็มีความน่าสนใจในตัวมัน', truncated=False, entities={'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': []}, source='Twitter for iPad', source_url='http://twitter.com/#!/download/ipad', in_reply_to_status_id=None, in_reply_to_status_id_str=None, in_reply_to_user_id=None, in_reply_to_user_id_str=None, in_reply_to_screen_name=None, author=User(_api=<tweepy.api.API object at 0x00000222DCE694A8>, _json={'id': 864638390, 'id_str': '864638390', 'name': 'คุณหยอยหาที่ฝึกงาน', 'screen_name': '_Greenslime_', 'location': '', 'description': 'ก็แค่ผู้ชายหัวหยอยหยอยคนนึง', 'url': 'https://t.co/iKw3FeMKuH', 'entities': {'url': {'urls': [{'url': 'https://t.co/iKw3FeMKuH', 'expanded_url': 'https://medium.com/@dondondiary', 'display_url': 'medium.com/@dondondiary', 'indices': [0, 23]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 213, 'friends_count': 294, 'listed_count': 0, 'created_at': 'Sat Oct 06 12:50:13 +0000 2012', 'favourites_count': 881, 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'verified': False, 'statuses_count': 12498, 'lang': 'th', 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': '8B542B', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme8/bg.gif', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme8/bg.gif', 'profile_backgrou ...
#
# Status(_api=<tweepy.api.API object at 0x00000222DCE694A8>, _json={'created_at': 'Sun Feb 17 17:43:13 +0000 2019', 'id': 1097189740317536261, 'id_str': '1097189740317536261', 'text': '@skconan ว่าละต้องมีคนคิดเหมือนกัน จริงๆ อยากให้น้องรู้จักภาพรวม แบบเรียนคอมไม่ได้มีแค่ทำ web นะ อยากให้เห็นภาพกว้า… https://t.co/2qTe8cKTJ8', 'truncated': True, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'skconan', 'name': 'Supakit', 'id': 1265009893, 'id_str': '1265009893', 'indices': [0, 8]}], 'urls': [{'url': 'https://t.co/2qTe8cKTJ8', 'expanded_url': 'https://twitter.com/i/web/status/1097189740317536261', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [117, 140]}]}, 'source': '<a href="http://twitter.com/#!/download/ipad" rel="nofollow">Twitter for iPad</a>', 'in_reply_to_status_id': 1097189027831152640, 'in_reply_to_status_id_str': '1097189027831152640', 'in_reply_to_user_id': 1265009893, 'in_reply_to_user_id_str': '1265009893', 'in_reply_to_screen_name': 'skconan', 'user': {'id': 864638390, 'id_str': '864638390', 'name': 'คุณหยอยหาที่ฝึกงาน', 'screen_name': '_Greenslime_', 'location': '', 'description': 'ก็แค่ผู้ชายหัวหยอยหยอยคนนึง', 'url': 'https://t.co/iKw3FeMKuH', 'entities': {'url': {'urls': [{'url': 'https://t.co/iKw3FeMKuH', 'expanded_url': 'https://medium.com/@dondondiary', 'display_url': 'medium.com/@dondondiary', 'indices': [0, 23]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 213, 'friends_count': 294, 'listed_count': 0, 'created_at': 'Sat Oct 06 12:50:13 +0000 2012', 'favourites_count': 881, 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'verified': False, 'statuses_count': 12498, 'lang': 'th', 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': '8B542B', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme8/bg.gif', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme8/bg.gif', 'profile_background_tile': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1041368010886246401/U5gr1jAC_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1041368010886246401/U5gr1jAC_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/864638390/1492800156', 'profile_link_color': '4EB402', 'profile_sidebar_border_color': 'FFFFFF', 'profile_sidebar_fill_color': 'EADEAA', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': False, 'default_profile': False, 'default_profile_image': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none'}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 0, 'favorite_count': 0, 'favorited': False, 'retweeted': False, 'lang': 'th'}, created_at=datetime.datetime(2019, 2, 17, 17, 43, 13), id=1097189740317536261, id_str='1097189740317536261', text='@skconan ว่าละต้องมีคนคิดเหมือนกัน จริงๆ อยากให้น้องรู้จักภาพรวม แบบเรียนคอมไม่ได้มีแค่ทำ web นะ อยากให้เห็นภาพกว้า… https://t.co/2qTe8cKTJ8', truncated=True, entities={'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'skconan', 'name': 'Supakit', 'id': 1265009893, 'id_str': '1265009893', 'indices': [0, 8]}], 'urls': [{'url': 'https://t.co/2qTe8cKTJ8', 'expanded_url': 'https://twitter.com/i/web/status/1097189740317536261', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [117, 140]}]}, source='Twitter for iPad', source_url='http://twitter.com/#!/download/ipad', in_reply_to_status_id=1097189027831152640, in_reply_to_status_id_str='1097189027831152640', in_reply_to_user_id=1265009893, in_reply_to_user_id_str='1265009893', in_reply_to_screen_name='skconan', author=User(_api=<tweepy.api.API object at 0x00000222DCE694A8>, _json={'id': 864638390, 'id_str': '864638390', 'name': 'คุณหยอยหาที่ฝึกงาน', 'screen_name': '_Greenslime_', 'location': '', 'descriptio ...
#
# Status(_api=<tweepy.api.API object at 0x00000222DCE694A8>, _json={'created_at': 'Sun Feb 17 16:46:03 +0000 2019', 'id': 1097175355415158785, 'id_str': '1097175355415158785', 'text': 'อยากทำแนะแนวเด็ก รร เก่ามาก เรื่อง ภาคคอมเข้าดีไหม 5555\nกลัวคนเข้ามาและผิดหวัง', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': []}, 'source': '<a href="http://twitter.com/#!/download/ipad" rel="nofollow">Twitter for iPad</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 864638390, 'id_str': '864638390', 'name': 'คุณหยอยหาที่ฝึกงาน', 'screen_name': '_Greenslime_', 'location': '', 'description': 'ก็แค่ผู้ชายหัวหยอยหยอยคนนึง', 'url': 'https://t.co/iKw3FeMKuH', 'entities': {'url': {'urls': [{'url': 'https://t.co/iKw3FeMKuH', 'expanded_url': 'https://medium.com/@dondondiary', 'display_url': 'medium.com/@dondondiary', 'indices': [0, 23]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 213, 'friends_count': 294, 'listed_count': 0, 'created_at': 'Sat Oct 06 12:50:13 +0000 2012', 'favourites_count': 881, 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'verified': False, 'statuses_count': 12498, 'lang': 'th', 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': '8B542B', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme8/bg.gif', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme8/bg.gif', 'profile_background_tile': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1041368010886246401/U5gr1jAC_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1041368010886246401/U5gr1jAC_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/864638390/1492800156', 'profile_link_color': '4EB402', 'profile_sidebar_border_color': 'FFFFFF', 'profile_sidebar_fill_color': 'EADEAA', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': False, 'default_profile': False, 'default_profile_image': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none'}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 0, 'favorite_count': 1, 'favorited': False, 'retweeted': False, 'lang': 'th'}, created_at=datetime.datetime(2019, 2, 17, 16, 46, 3), id=1097175355415158785, id_str='1097175355415158785', text='อยากทำแนะแนวเด็ก รร เก่ามาก เรื่อง ภาคคอมเข้าดีไหม 5555\nกลัวคนเข้ามาและผิดหวัง', truncated=False, entities={'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': []}, source='Twitter for iPad', source_url='http://twitter.com/#!/download/ipad', in_reply_to_status_id=None, in_reply_to_status_id_str=None, in_reply_to_user_id=None, in_reply_to_user_id_str=None, in_reply_to_screen_name=None, author=User(_api=<tweepy.api.API object at 0x00000222DCE694A8>, _json={'id': 864638390, 'id_str': '864638390', 'name': 'คุณหยอยหาที่ฝึกงาน', 'screen_name': '_Greenslime_', 'location': '', 'description': 'ก็แค่ผู้ชายหัวหยอยหยอยคนนึง', 'url': 'https://t.co/iKw3FeMKuH', 'entities': {'url': {'urls': [{'url': 'https://t.co/iKw3FeMKuH', 'expanded_url': 'https://medium.com/@dondondiary', 'display_url': 'medium.com/@dondondiary', 'indices': [0, 23]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 213, 'friends_count': 294, 'listed_count': 0, 'created_at': 'Sat Oct 06 12:50:13 +0000 2012', 'favourites_count': 881, 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'verified': False, 'statuses_count': 12498, 'lang': 'th', 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': '8B542B', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme8/bg.gif', 'profile_background ...
#
# Status(_api=<tweepy.api.API object at 0x00000222DCE694A8>, _json={'created_at': 'Sun Feb 17 16:45:06 +0000 2019', 'id': 1097175115232497665, 'id_str': '1097175115232497665', 'text': '@skconan น้ำตาไหลสิ 555 me too clean data ยากจัด', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'skconan', 'name': 'Supakit', 'id': 1265009893, 'id_str': '1265009893', 'indices': [0, 8]}], 'urls': []}, 'source': '<a href="http://twitter.com/#!/download/ipad" rel="nofollow">Twitter for iPad</a>', 'in_reply_to_status_id': 1097110197074485250, 'in_reply_to_status_id_str': '1097110197074485250', 'in_reply_to_user_id': 1265009893, 'in_reply_to_user_id_str': '1265009893', 'in_reply_to_screen_name': 'skconan', 'user': {'id': 864638390, 'id_str': '864638390', 'name': 'คุณหยอยหาที่ฝึกงาน', 'screen_name': '_Greenslime_', 'location': '', 'description': 'ก็แค่ผู้ชายหัวหยอยหยอยคนนึง', 'url': 'https://t.co/iKw3FeMKuH', 'entities': {'url': {'urls': [{'url': 'https://t.co/iKw3FeMKuH', 'expanded_url': 'https://medium.com/@dondondiary', 'display_url': 'medium.com/@dondondiary', 'indices': [0, 23]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 213, 'friends_count': 294, 'listed_count': 0, 'created_at': 'Sat Oct 06 12:50:13 +0000 2012', 'favourites_count': 881, 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'verified': False, 'statuses_count': 12498, 'lang': 'th', 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': '8B542B', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme8/bg.gif', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme8/bg.gif', 'profile_background_tile': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1041368010886246401/U5gr1jAC_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1041368010886246401/U5gr1jAC_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/864638390/1492800156', 'profile_link_color': '4EB402', 'profile_sidebar_border_color': 'FFFFFF', 'profile_sidebar_fill_color': 'EADEAA', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': False, 'default_profile': False, 'default_profile_image': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none'}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 0, 'favorite_count': 0, 'favorited': False, 'retweeted': False, 'lang': 'und'}, created_at=datetime.datetime(2019, 2, 17, 16, 45, 6), id=1097175115232497665, id_str='1097175115232497665', text='@skconan น้ำตาไหลสิ 555 me too clean data ยากจัด', truncated=False, entities={'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'skconan', 'name': 'Supakit', 'id': 1265009893, 'id_str': '1265009893', 'indices': [0, 8]}], 'urls': []}, source='Twitter for iPad', source_url='http://twitter.com/#!/download/ipad', in_reply_to_status_id=1097110197074485250, in_reply_to_status_id_str='1097110197074485250', in_reply_to_user_id=1265009893, in_reply_to_user_id_str='1265009893', in_reply_to_screen_name='skconan', author=User(_api=<tweepy.api.API object at 0x00000222DCE694A8>, _json={'id': 864638390, 'id_str': '864638390', 'name': 'คุณหยอยหาที่ฝึกงาน', 'screen_name': '_Greenslime_', 'location': '', 'description': 'ก็แค่ผู้ชายหัวหยอยหยอยคนนึง', 'url': 'https://t.co/iKw3FeMKuH', 'entities': {'url': {'urls': [{'url': 'https://t.co/iKw3FeMKuH', 'expanded_url': 'https://medium.com/@dondondiary', 'display_url': 'medium.com/@dondondiary', 'indices': [0, 23]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 213, 'friends_count': 294, 'listed_count': 0, 'created_at': 'Sat Oct 06 12:50:13 +0000 2012', 'favourites_count': 881, 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'verified': False, 'statuses_count ...
#
# Status(_api=<tweepy.api.API object at 0x00000222DCE694A8>, _json={'created_at': 'Fri Feb 15 15:29:48 +0000 2019', 'id': 1096431389702942720, 'id_str': '1096431389702942720', 'text': 'RT @JennluvxJae: อิสัส กุขำแรงมาก5555555555555555555555555555555555555555555555\n#อนาคตใหม่\n#ฟ้ารักพ่อ \n#พลังประชารัฐ \n#ฟ้ารักพ่อเพราะนโยบาย…', 'truncated': False, 'entities': {'hashtags': [{'text': 'อนาคตใหม่', 'indices': [80, 90]}, {'text': 'ฟ้ารักพ่อ', 'indices': [91, 101]}, {'text': 'พลังประชารัฐ', 'indices': [103, 116]}], 'symbols': [], 'user_mentions': [{'screen_name': 'JennluvxJae', 'name': 'เจนลัฟซ์แจ🦄', 'id': 978974871697829888, 'id_str': '978974871697829888', 'indices': [3, 15]}], 'urls': []}, 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 864638390, 'id_str': '864638390', 'name': 'คุณหยอยหาที่ฝึกงาน', 'screen_name': '_Greenslime_', 'location': '', 'description': 'ก็แค่ผู้ชายหัวหยอยหยอยคนนึง', 'url': 'https://t.co/iKw3FeMKuH', 'entities': {'url': {'urls': [{'url': 'https://t.co/iKw3FeMKuH', 'expanded_url': 'https://medium.com/@dondondiary', 'display_url': 'medium.com/@dondondiary', 'indices': [0, 23]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 213, 'friends_count': 294, 'listed_count': 0, 'created_at': 'Sat Oct 06 12:50:13 +0000 2012', 'favourites_count': 881, 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'verified': False, 'statuses_count': 12498, 'lang': 'th', 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': '8B542B', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme8/bg.gif', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme8/bg.gif', 'profile_background_tile': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1041368010886246401/U5gr1jAC_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1041368010886246401/U5gr1jAC_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/864638390/1492800156', 'profile_link_color': '4EB402', 'profile_sidebar_border_color': 'FFFFFF', 'profile_sidebar_fill_color': 'EADEAA', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': False, 'default_profile': False, 'default_profile_image': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none'}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'retweeted_status': {'created_at': 'Sun Feb 10 12:32:35 +0000 2019', 'id': 1094574850327293953, 'id_str': '1094574850327293953', 'text': 'อิสัส กุขำแรงมาก5555555555555555555555555555555555555555555555\n#อนาคตใหม่\n#ฟ้ารักพ่อ \n#พลังประชารัฐ… https://t.co/poyPdUlXnv', 'truncated': True, 'entities': {'hashtags': [{'text': 'อนาคตใหม่', 'indices': [63, 73]}, {'text': 'ฟ้ารักพ่อ', 'indices': [74, 84]}, {'text': 'พลังประชารัฐ', 'indices': [86, 99]}], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/poyPdUlXnv', 'expanded_url': 'https://twitter.com/i/web/status/1094574850327293953', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [101, 124]}]}, 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 978974871697829888, 'id_str': '978974871697829888', 'name': 'เจนลัฟซ์แจ🦄 | คิดถึงน้งยองแจ', 'screen_name': 'JennluvxJae', 'location': 'ałłjæšhippęr.', 'description': "I'm turning 15 this year 🖤 | นุ้งน่ารักจริงๆนะ | เลาว์เปงแม่ |  ลัทธิยองแจ | การอวยลูกเป็นเรื่องปกติ | เหนือเมนคือน้องยองแจในร่างหลัว 💙@GOTYJ_Ars_Vita💛", 'url': 'https: ...
#
# Status(_api=<tweepy.api.API object at 0x00000222DCE694A8>, _json={'created_at': 'Fri Feb 15 15:23:47 +0000 2019', 'id': 1096429876079280128, 'id_str': '1096429876079280128', 'text': 'เสียดาย.', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': []}, 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 864638390, 'id_str': '864638390', 'name': 'คุณหยอยหาที่ฝึกงาน', 'screen_name': '_Greenslime_', 'location': '', 'description': 'ก็แค่ผู้ชายหัวหยอยหยอยคนนึง', 'url': 'https://t.co/iKw3FeMKuH', 'entities': {'url': {'urls': [{'url': 'https://t.co/iKw3FeMKuH', 'expanded_url': 'https://medium.com/@dondondiary', 'display_url': 'medium.com/@dondondiary', 'indices': [0, 23]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 213, 'friends_count': 294, 'listed_count': 0, 'created_at': 'Sat Oct 06 12:50:13 +0000 2012', 'favourites_count': 881, 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'verified': False, 'statuses_count': 12498, 'lang': 'th', 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': '8B542B', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme8/bg.gif', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme8/bg.gif', 'profile_background_tile': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1041368010886246401/U5gr1jAC_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1041368010886246401/U5gr1jAC_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/864638390/1492800156', 'profile_link_color': '4EB402', 'profile_sidebar_border_color': 'FFFFFF', 'profile_sidebar_fill_color': 'EADEAA', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': False, 'default_profile': False, 'default_profile_image': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none'}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 0, 'favorite_count': 0, 'favorited': False, 'retweeted': False, 'lang': 'th'}, created_at=datetime.datetime(2019, 2, 15, 15, 23, 47), id=1096429876079280128, id_str='1096429876079280128', text='เสียดาย.', truncated=False, entities={'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': []}, source='Twitter for Android', source_url='http://twitter.com/download/android', in_reply_to_status_id=None, in_reply_to_status_id_str=None, in_reply_to_user_id=None, in_reply_to_user_id_str=None, in_reply_to_screen_name=None, author=User(_api=<tweepy.api.API object at 0x00000222DCE694A8>, _json={'id': 864638390, 'id_str': '864638390', 'name': 'คุณหยอยหาที่ฝึกงาน', 'screen_name': '_Greenslime_', 'location': '', 'description': 'ก็แค่ผู้ชายหัวหยอยหยอยคนนึง', 'url': 'https://t.co/iKw3FeMKuH', 'entities': {'url': {'urls': [{'url': 'https://t.co/iKw3FeMKuH', 'expanded_url': 'https://medium.com/@dondondiary', 'display_url': 'medium.com/@dondondiary', 'indices': [0, 23]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 213, 'friends_count': 294, 'listed_count': 0, 'created_at': 'Sat Oct 06 12:50:13 +0000 2012', 'favourites_count': 881, 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'verified': False, 'statuses_count': 12498, 'lang': 'th', 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': '8B542B', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme8/bg.gif', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme8/bg.gif', 'profile_background_tile': True, 'profile_image_url': 'http://p ...
#
# Status(_api=<tweepy.api.API object at 0x00000222DCE694A8>, _json={'created_at': 'Wed Feb 13 17:03:36 +0000 2019', 'id': 1095730220852596737, 'id_str': '1095730220852596737', 'text': 'RT @SkulLaeEy: เจอในเฟช เขาบอกให้ดู 4 วิแรกแล้วเลื่อนไปตอนท้ายๆนี่ก็ลองทำ นั่งขำอยู่ 10 นาทีอีสัด 5555555555555 https://t.co/FVUpBBePy8', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'SkulLaeEy', 'name': '❥Wufan Darkness✪', 'id': 111477946, 'id_str': '111477946', 'indices': [3, 13]}], 'urls': [], 'media': [{'id': 1095321782146351104, 'id_str': '1095321782146351104', 'indices': [112, 135], 'media_url': 'http://pbs.twimg.com/ext_tw_video_thumb/1095321782146351104/pu/img/uprCDe939Gl-wDoK.jpg', 'media_url_https': 'https://pbs.twimg.com/ext_tw_video_thumb/1095321782146351104/pu/img/uprCDe939Gl-wDoK.jpg', 'url': 'https://t.co/FVUpBBePy8', 'display_url': 'pic.twitter.com/FVUpBBePy8', 'expanded_url': 'https://twitter.com/SkulLaeEy/status/1095321952644820997/video/1', 'type': 'photo', 'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'}, 'small': {'w': 383, 'h': 680, 'resize': 'fit'}, 'large': {'w': 720, 'h': 1280, 'resize': 'fit'}, 'medium': {'w': 675, 'h': 1200, 'resize': 'fit'}}, 'source_status_id': 1095321952644820997, 'source_status_id_str': '1095321952644820997', 'source_user_id': 111477946, 'source_user_id_str': '111477946'}]}, 'extended_entities': {'media': [{'id': 1095321782146351104, 'id_str': '1095321782146351104', 'indices': [112, 135], 'media_url': 'http://pbs.twimg.com/ext_tw_video_thumb/1095321782146351104/pu/img/uprCDe939Gl-wDoK.jpg', 'media_url_https': 'https://pbs.twimg.com/ext_tw_video_thumb/1095321782146351104/pu/img/uprCDe939Gl-wDoK.jpg', 'url': 'https://t.co/FVUpBBePy8', 'display_url': 'pic.twitter.com/FVUpBBePy8', 'expanded_url': 'https://twitter.com/SkulLaeEy/status/1095321952644820997/video/1', 'type': 'video', 'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'}, 'small': {'w': 383, 'h': 680, 'resize': 'fit'}, 'large': {'w': 720, 'h': 1280, 'resize': 'fit'}, 'medium': {'w': 675, 'h': 1200, 'resize': 'fit'}}, 'source_status_id': 1095321952644820997, 'source_status_id_str': '1095321952644820997', 'source_user_id': 111477946, 'source_user_id_str': '111477946', 'video_info': {'aspect_ratio': [9, 16], 'duration_millis': 63058, 'variants': [{'bitrate': 832000, 'content_type': 'video/mp4', 'url': 'https://video.twimg.com/ext_tw_video/1095321782146351104/pu/vid/360x640/vNWe0s3_FeC_-nuY.mp4?tag=6'}, {'bitrate': 632000, 'content_type': 'video/mp4', 'url': 'https://video.twimg.com/ext_tw_video/1095321782146351104/pu/vid/320x568/KJrqkKt22pFOBnk9.mp4?tag=6'}, {'content_type': 'application/x-mpegURL', 'url': 'https://video.twimg.com/ext_tw_video/1095321782146351104/pu/pl/b_YXU6d1qKagnxgI.m3u8?tag=6'}, {'bitrate': 2176000, 'content_type': 'video/mp4', 'url': 'https://video.twimg.com/ext_tw_video/1095321782146351104/pu/vid/720x1280/PeeuTb7VEIjLaDLI.mp4?tag=6'}]}, 'additional_media_info': {'monetizable': False, 'source_user': {'id': 111477946, 'id_str': '111477946', 'name': '❥Wufan Darkness✪', 'screen_name': 'SkulLaeEy', 'location': 'GALAXY', 'description': "★KrisWu ❥ เกรียนกากกาม ทาสคริสสายแข็ง ❥#ติ่งพี่เอ๋ย : KRISYEOL&EXO12 : If you can't live longer,live deeper 🔥", 'url': 'https://t.co/w1ydVltGT2', 'entities': {'url': {'urls': [{'url': 'https://t.co/w1ydVltGT2', 'expanded_url': 'http://0ctogus.forumth.com/f25-forum', 'display_url': '0ctogus.forumth.com/f25-forum', 'indices': [0, 23]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 48137, 'friends_count': 80, 'listed_count': 64, 'created_at': 'Fri Feb 05 02:15:58 +0000 2010', 'favourites_count': 2927, 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'verified': False, 'statuses_count': 241377, 'lang': 'en', 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': '1A1B1F', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/t ...
#
# ...
#
# Status(_api=<tweepy.api.API object at 0x00000222DCE694A8>, _json={'created_at': 'Sat Feb 09 09:37:20 +0000 2019', 'id': 1094168362387566592, 'id_str': '1094168362387566592', 'text': 'RT @pnic_k: ชอบอันนี้แม่งโครตจริง #TUCUBALL73 https://t.co/Nd527Dts5I', 'truncated': False, 'entities': {'hashtags': [{'text': 'TUCUBALL73', 'indices': [34, 45]}], 'symbols': [], 'user_mentions': [{'screen_name': 'pnic_k', 'name': "แบบว่ากระเดือก'งง", 'id': 1595895301, 'id_str': '1595895301', 'indices': [3, 10]}], 'urls': [], 'media': [{'id': 1094138550725926912, 'id_str': '1094138550725926912', 'indices': [46, 69], 'media_url': 'http://pbs.twimg.com/media/Dy8pNwMUYAA66Gv.jpg', 'media_url_https': 'https://pbs.twimg.com/media/Dy8pNwMUYAA66Gv.jpg', 'url': 'https://t.co/Nd527Dts5I', 'display_url': 'pic.twitter.com/Nd527Dts5I', 'expanded_url': 'https://twitter.com/pnic_k/status/1094138559731195904/photo/1', 'type': 'photo', 'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'}, 'medium': {'w': 1200, 'h': 675, 'resize': 'fit'}, 'small': {'w': 680, 'h': 383, 'resize': 'fit'}, 'large': {'w': 2048, 'h': 1152, 'resize': 'fit'}}, 'source_status_id': 1094138559731195904, 'source_status_id_str': '1094138559731195904', 'source_user_id': 1595895301, 'source_user_id_str': '1595895301'}]}, 'extended_entities': {'media': [{'id': 1094138550725926912, 'id_str': '1094138550725926912', 'indices': [46, 69], 'media_url': 'http://pbs.twimg.com/media/Dy8pNwMUYAA66Gv.jpg', 'media_url_https': 'https://pbs.twimg.com/media/Dy8pNwMUYAA66Gv.jpg', 'url': 'https://t.co/Nd527Dts5I', 'display_url': 'pic.twitter.com/Nd527Dts5I', 'expanded_url': 'https://twitter.com/pnic_k/status/1094138559731195904/photo/1', 'type': 'photo', 'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'}, 'medium': {'w': 1200, 'h': 675, 'resize': 'fit'}, 'small': {'w': 680, 'h': 383, 'resize': 'fit'}, 'large': {'w': 2048, 'h': 1152, 'resize': 'fit'}}, 'source_status_id': 1094138559731195904, 'source_status_id_str': '1094138559731195904', 'source_user_id': 1595895301, 'source_user_id_str': '1595895301'}]}, 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 864638390, 'id_str': '864638390', 'name': 'คุณหยอยหาที่ฝึกงาน', 'screen_name': '_Greenslime_', 'location': '', 'description': 'ก็แค่ผู้ชายหัวหยอยหยอยคนนึง', 'url': 'https://t.co/iKw3FeMKuH', 'entities': {'url': {'urls': [{'url': 'https://t.co/iKw3FeMKuH', 'expanded_url': 'https://medium.com/@dondondiary', 'display_url': 'medium.com/@dondondiary', 'indices': [0, 23]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 213, 'friends_count': 294, 'listed_count': 0, 'created_at': 'Sat Oct 06 12:50:13 +0000 2012', 'favourites_count': 881, 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'verified': False, 'statuses_count': 12498, 'lang': 'th', 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': '8B542B', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme8/bg.gif', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme8/bg.gif', 'profile_background_tile': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1041368010886246401/U5gr1jAC_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1041368010886246401/U5gr1jAC_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/864638390/1492800156', 'profile_link_color': '4EB402', 'profile_sidebar_border_color': 'FFFFFF', 'profile_sidebar_fill_color': 'EADEAA', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': False, 'default_profile': False, 'default_profile_image': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translat ...
#
# Status(_api=<tweepy.api.API object at 0x00000222DCE694A8>, _json={'created_at': 'Sat Feb 09 09:35:40 +0000 2019', 'id': 1094167939647848448, 'id_str': '1094167939647848448', 'text': 'RT @PePPeR0528: ป้ายนี้โดนเก็บบบบบ #TUCUBALL73 https://t.co/rGFkmA5VBK', 'truncated': False, 'entities': {'hashtags': [{'text': 'TUCUBALL73', 'indices': [35, 46]}], 'symbols': [], 'user_mentions': [{'screen_name': 'PePPeR0528', 'name': 'Pepp. K', 'id': 75523288, 'id_str': '75523288', 'indices': [3, 14]}], 'urls': [], 'media': [{'id': 1094142388107304965, 'id_str': '1094142388107304965', 'indices': [47, 70], 'media_url': 'http://pbs.twimg.com/media/Dy8stHjVYAU66fl.jpg', 'media_url_https': 'https://pbs.twimg.com/media/Dy8stHjVYAU66fl.jpg', 'url': 'https://t.co/rGFkmA5VBK', 'display_url': 'pic.twitter.com/rGFkmA5VBK', 'expanded_url': 'https://twitter.com/PePPeR0528/status/1094142399968796672/photo/1', 'type': 'photo', 'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'}, 'medium': {'w': 576, 'h': 1024, 'resize': 'fit'}, 'small': {'w': 383, 'h': 680, 'resize': 'fit'}, 'large': {'w': 576, 'h': 1024, 'resize': 'fit'}}, 'source_status_id': 1094142399968796672, 'source_status_id_str': '1094142399968796672', 'source_user_id': 75523288, 'source_user_id_str': '75523288'}]}, 'extended_entities': {'media': [{'id': 1094142388107304965, 'id_str': '1094142388107304965', 'indices': [47, 70], 'media_url': 'http://pbs.twimg.com/media/Dy8stHjVYAU66fl.jpg', 'media_url_https': 'https://pbs.twimg.com/media/Dy8stHjVYAU66fl.jpg', 'url': 'https://t.co/rGFkmA5VBK', 'display_url': 'pic.twitter.com/rGFkmA5VBK', 'expanded_url': 'https://twitter.com/PePPeR0528/status/1094142399968796672/photo/1', 'type': 'photo', 'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'}, 'medium': {'w': 576, 'h': 1024, 'resize': 'fit'}, 'small': {'w': 383, 'h': 680, 'resize': 'fit'}, 'large': {'w': 576, 'h': 1024, 'resize': 'fit'}}, 'source_status_id': 1094142399968796672, 'source_status_id_str': '1094142399968796672', 'source_user_id': 75523288, 'source_user_id_str': '75523288'}]}, 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 864638390, 'id_str': '864638390', 'name': 'คุณหยอยหาที่ฝึกงาน', 'screen_name': '_Greenslime_', 'location': '', 'description': 'ก็แค่ผู้ชายหัวหยอยหยอยคนนึง', 'url': 'https://t.co/iKw3FeMKuH', 'entities': {'url': {'urls': [{'url': 'https://t.co/iKw3FeMKuH', 'expanded_url': 'https://medium.com/@dondondiary', 'display_url': 'medium.com/@dondondiary', 'indices': [0, 23]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 213, 'friends_count': 294, 'listed_count': 0, 'created_at': 'Sat Oct 06 12:50:13 +0000 2012', 'favourites_count': 881, 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'verified': False, 'statuses_count': 12498, 'lang': 'th', 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': '8B542B', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme8/bg.gif', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme8/bg.gif', 'profile_background_tile': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1041368010886246401/U5gr1jAC_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1041368010886246401/U5gr1jAC_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/864638390/1492800156', 'profile_link_color': '4EB402', 'profile_sidebar_border_color': 'FFFFFF', 'profile_sidebar_fill_color': 'EADEAA', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': False, 'default_profile': False, 'default_profile_image': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': ' ...
#
# Status(_api=<tweepy.api.API object at 0x00000222DCE694A8>, _json={'created_at': 'Wed Feb 06 16:15:11 +0000 2019', 'id': 1093181321268973568, 'id_str': '1093181321268973568', 'text': 'RT @evermini_: #เมอา conan ของคนอื่น กับ conan ของฉันตอนอ่านแท็ก อห.เอ้ยผิดเองงง https://t.co/uSP4mS8XyN', 'truncated': False, 'entities': {'hashtags': [{'text': 'เมอา', 'indices': [15, 20]}], 'symbols': [], 'user_mentions': [{'screen_name': 'evermini_', 'name': '𝐥𝐢𝐥 𝐭.\U0001f996', 'id': 2893645027, 'id_str': '2893645027', 'indices': [3, 13]}], 'urls': [], 'media': [{'id': 1092884725683736576, 'id_str': '1092884725683736576', 'indices': [81, 104], 'media_url': 'http://pbs.twimg.com/media/Dyq03h7UUAAurZE.jpg', 'media_url_https': 'https://pbs.twimg.com/media/Dyq03h7UUAAurZE.jpg', 'url': 'https://t.co/uSP4mS8XyN', 'display_url': 'pic.twitter.com/uSP4mS8XyN', 'expanded_url': 'https://twitter.com/evermini_/status/1092884744075792384/photo/1', 'type': 'photo', 'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'}, 'medium': {'w': 675, 'h': 1200, 'resize': 'fit'}, 'large': {'w': 750, 'h': 1334, 'resize': 'fit'}, 'small': {'w': 382, 'h': 680, 'resize': 'fit'}}, 'source_status_id': 1092884744075792384, 'source_status_id_str': '1092884744075792384', 'source_user_id': 2893645027, 'source_user_id_str': '2893645027'}]}, 'extended_entities': {'media': [{'id': 1092884725683736576, 'id_str': '1092884725683736576', 'indices': [81, 104], 'media_url': 'http://pbs.twimg.com/media/Dyq03h7UUAAurZE.jpg', 'media_url_https': 'https://pbs.twimg.com/media/Dyq03h7UUAAurZE.jpg', 'url': 'https://t.co/uSP4mS8XyN', 'display_url': 'pic.twitter.com/uSP4mS8XyN', 'expanded_url': 'https://twitter.com/evermini_/status/1092884744075792384/photo/1', 'type': 'photo', 'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'}, 'medium': {'w': 675, 'h': 1200, 'resize': 'fit'}, 'large': {'w': 750, 'h': 1334, 'resize': 'fit'}, 'small': {'w': 382, 'h': 680, 'resize': 'fit'}}, 'source_status_id': 1092884744075792384, 'source_status_id_str': '1092884744075792384', 'source_user_id': 2893645027, 'source_user_id_str': '2893645027'}, {'id': 1092884733833338881, 'id_str': '1092884733833338881', 'indices': [81, 104], 'media_url': 'http://pbs.twimg.com/media/Dyq04ASVYAEJZrG.jpg', 'media_url_https': 'https://pbs.twimg.com/media/Dyq04ASVYAEJZrG.jpg', 'url': 'https://t.co/uSP4mS8XyN', 'display_url': 'pic.twitter.com/uSP4mS8XyN', 'expanded_url': 'https://twitter.com/evermini_/status/1092884744075792384/photo/1', 'type': 'photo', 'sizes': {'small': {'w': 425, 'h': 680, 'resize': 'fit'}, 'large': {'w': 1080, 'h': 1726, 'resize': 'fit'}, 'thumb': {'w': 150, 'h': 150, 'resize': 'crop'}, 'medium': {'w': 751, 'h': 1200, 'resize': 'fit'}}, 'source_status_id': 1092884744075792384, 'source_status_id_str': '1092884744075792384', 'source_user_id': 2893645027, 'source_user_id_str': '2893645027'}]}, 'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 864638390, 'id_str': '864638390', 'name': 'คุณหยอยหาที่ฝึกงาน', 'screen_name': '_Greenslime_', 'location': '', 'description': 'ก็แค่ผู้ชายหัวหยอยหยอยคนนึง', 'url': 'https://t.co/iKw3FeMKuH', 'entities': {'url': {'urls': [{'url': 'https://t.co/iKw3FeMKuH', 'expanded_url': 'https://medium.com/@dondondiary', 'display_url': 'medium.com/@dondondiary', 'indices': [0, 23]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 213, 'friends_count': 294, 'listed_count': 0, 'created_at': 'Sat Oct 06 12:50:13 +0000 2012', 'favourites_count': 881, 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'verified': False, 'statuses_count': 12498, 'lang': 'th', 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': '8B542B', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme8/bg ...

# %% [markdown]
# Note that you can print any specified attribute from the JSON object, e.g.,
# > the date the tweet was create by `print(tweet.created_at)`,<br>
# > the name of the tweeter by `print(tweet.user.screen_name)`,<br>
# > or the location of the tweeter by `print(tweet.user.location)`
#
# If you need to dump each JSON object, you can use the following statements:
# `import json`
# and
# `json_str = json.dumps(tweet._json)`
#
# ### 1.3 Finding Tweets using a Keyword
# Getting the most recent tweets that contain a keyword. This can be extremely useful if you want to monitor specifically mentioned topics in the Twitter world, or even to see how your business is getting mentioned.
#
# From the <a href="http://docs.tweepy.org/en/v3.5.0/api.html" target="_blank">Tweepy documentation</a>, the `search()` function is the best tool to accomplish our goal.
#
# <img src="function_search.png" alt="The search() function" title="The search() function" width="60%" align="left" />

# %% [markdown]
# The most important parameter here is `q` (the query parameter), which is the keyword we're searching for.
#
# We can also set the language parameter so we don't get any tweets from an unwanted language. Let's only return English ("en") tweets.
#
# We can now modify our code to reflect the changes we want to make. We first create variables to store our parameters (query and language), and then call the function via the API object. Let's also print the screen name, of the user that created the tweet, in our loop.

# %%
# The search term you want to find
query = "SPECIFIC-KEYWORDS"

# Language code (follows ISO 639-1 standards)
language = "en"

# Calling the search function with our parameters
results = api.search(q=query, lang=language)

# foreach through all tweets pulled
for tweet in results:
    # printing the user's screen name with his corresponding tweet
    print(tweet.user.screen_name,"Tweeted:",tweet.text)
    print()

# %% [markdown]
# ## 2) Depicting Users' Relationship
# Normally, users follow their interests on Twitter through both one-way and mutual following relationships. There are two kinds of person related to a user:
# * Friends - persons whom you are followed
# * Followers - persons who follow you
#
# ### 2.1 Friends
# From the <a href="http://docs.tweepy.org/en/v3.5.0/api.html" target="_blank">Tweepy documentation</a>, the `friends_ids()` together with `get_user()` functions are used to accomplish our goal.
#
# <img src="function_friends_ids.png" alt="The friends_ids() function" title="The friends_ids() function" width="60%" align="left" />
# <br>
# <img src="function_get_user.png" alt="The get_user() function" title="The get_user() function" width="60%" align="left" />

# %%
# The Twitter user who we want to get his friends
name = "SPECIFIC-USER"

# Calling the friends_ids function with our parameters
results = api.friends_ids(screen_name=name)

# foreach through all friends pulled
for id in results:
    user_info = api.get_user(id)
    # printing the user's id and screen name
    print(id,"->",user_info.screen_name)

# %% [markdown]
# ### 2.2 Followers
# From the <a href="http://docs.tweepy.org/en/v3.5.0/api.html" target="_blank">Tweepy documentation</a>, the `followers_ids()` together with `get_user()` functions are used to accomplish our goal.
#
# <img src="function_followers_ids.png" alt="The followers_ids() function" title="The followers_ids() function" width="60%" align="left" />

# %%
# The Twitter user who we want to get his followers
name = "SPECIFIC-USER"

# Calling the friends_ids function with our parameters
results = api.followers_ids(screen_name=name)

# foreach through all followers pulled
for id in results:
    user_info = api.get_user(id)
    # printing the user's id and screen name
    print(id,"->",user_info.screen_name)

# %% [markdown]
# ## 3) Exploring Trending Topics
# You can ask Twitter for the topics that are currently trending worldwide (or more specific locales).
#
# From the <a href="http://docs.tweepy.org/en/v3.5.0/api.html" target="_blank">Tweepy documentation</a>, the `trends_place()` function is used to accomplish our goal.
#
# <img src="function_trends_place.png" alt="The trends_place() function" title="The trends_place() function" width="60%" align="left" />

# %% [markdown]
# The key parameter needed to specify is `id`, referred to "Where On Earth Identifier (WOEID)". The WOEID is a unique 32-bit reference identifier, originally defined by GeoPlanet and now assigned by Yahoo!, that identifies any feature on Earth. For example, the world's WOEID is 1, and Bangkok's WOEID is 1225448, respectively. To find your WOEID, you simply use <a href="http://www.woeidlookup.com" target="_blank">WOEID Lookup</a>
#
# However, the trending topics are cached for 5 minutes. So that you do not need to request more frequently.

# %%
# The WOE code to ask for trends (i.e., WOEID = 1 means the world)
woeid = 1

# Calling the trends_place function with our parameters
results = api.trends_place(woeid)

# foreach through all trends pulled
for trend in results[0]['trends']:
    # grab the name from each trend
    print(trend['name'])
